# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9a0887ee-7986-4a13-9f4e-321de9e4e2a1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9a0887ee-7986-4a13-9f4e-321de9e4e2a1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !ls /root/.cache/kagglehub/datasets/balraj98/deepglobe-road-extraction-dataset/versions/2
# Out:
# class_dict.csv	metadata.csv  test  train  valid

# %%
# !git clone https://github.com/ShenweiXie/PaRK-Detect.git
# %cd PaRK-Detect

# %%
# !ls /root/.cache/kagglehub/datasets/balraj98/deepglobe-road-extraction-dataset/versions/2/train

# %%
# !pip install torch torchvision albumentations opencv-python-headless tqdm

# %%
# !mkdir -p temp_data
# !unzip /content/train.zip -d temp_data/
# Out:
# Archive:  /content/train.zip
#    creating: temp_data/train/
#   inflating: temp_data/train/104_mask.mat
#   inflating: temp_data/train/104_mask.png
#   inflating: temp_data/train/104_sat.jpg
#   inflating: temp_data/train/1054_mask.mat
#   inflating: temp_data/train/1054_mask.png
#   inflating: temp_data/train/1054_sat.jpg
#   inflating: temp_data/train/113_mask.mat
#   inflating: temp_data/train/113_mask.png
#   inflating: temp_data/train/113_sat.jpg
#   inflating: temp_data/train/1849_mask.mat
#   inflating: temp_data/train/1849_mask.png
#   inflating: temp_data/train/1849_sat.jpg
#   inflating: temp_data/train/1934_mask.mat
#   inflating: temp_data/train/1934_mask.png
#   inflating: temp_data/train/1934_sat.jpg
#   inflating: temp_data/train/1945_mask.mat
#   inflating: temp_data/train/1945_mask.png
#   inflating: temp_data/train/1945_sat.jpg
#   inflating: temp_data/train/2129_mask.mat
#   inflating: temp_data/train/2129_mask.png
#   inflating: temp_data/train/2129_sat.jpg
# ...

# %%
# Move images
# !mv temp_data/train/*sat*.* preprocess/image/ || true

# %%
# Move masks
# !mv temp_data/train/*mask*.* preprocess/mask/ || true

# %%
# !python preprocess/generate_labels.py
# Out:
# Generating patch-wise labels: 100% 60/60 [00:00<00:00, 60.91it/s]

# %%
# !cp -r /content/PaRK-Detect /content/drive/MyDrive/

# %%
# !cp -r /content/train.zip /content/drive/MyDrive/

# %%
# %cd /content/drive/MyDrive/PaRK-Detect
# Out:
# /content/drive/MyDrive/PaRK-Detect

# %%
import os
img_dir = '/content/drive/MyDrive/PaRK-Detect/preprocess/image'
print(sorted(os.listdir(img_dir))[:5])  # Sample output
# Out:
# ['104_sat.jpg', '1054_sat.jpg', '113_sat.jpg', '1849_sat.jpg', '1934_sat.jpg']

# %%
# %cd /content/drive/MyDrive/PaRK-Detect
#!python preprocess/generate_labels.py
# Out:
# /content/drive/MyDrive/PaRK-Detect

# %%
# !python train.py
# Out:
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet34_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet34_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# ...

# %%
# !python test_without_TTA_mask_keypoints_link.py \
  --model log04_dink34.th \
  --weights_dir weights \
  --output_dir submits
# Out:
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet34_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet34_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# 0.0      0.02

# %%
# !rm -rf /content/drive/MyDrive/PaRK-Detect/submits/log04_dink34_without_TTA/

# %%
# !python test_with_TTA_mask_keypoints_link.py \
  --model log04_dink34.th \
  --weights_dir weights \
  --output_dir submits_with_TTA
# Out:
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet34_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet34_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# 0.0      0.01

# %%
# !python convert_mask_to_roads.py

# %%
# !python convert_mask_to_roads.py
